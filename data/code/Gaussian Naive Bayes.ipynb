# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_predict
from mlxtend.plotting import plot_confusion_matrix
from mlxtend.evaluate import confusion_matrix

import warnings
warnings.filterwarnings('ignore')

from sklearn.naive_bayes import GaussianNB

# %%
x = np.genfromtxt('preprocessed_x_bathroom.csv', delimiter=',')
y = np.genfromtxt('preprocessed_y_bathroom.csv', delimiter=',', dtype= None)

# %%
gs=GaussianNB()

# %%
feature_names=[]
for names in y:
  if names not in feature_names:
    feature_names.append(names)
#feature_names

# %%
for splits in range(3,8):
    fin_pred = cross_val_predict(gs, x, y, cv=splits)

    print("Guassian, splits=",splits)
    print(classification_report(y, fin_pred))

    cm = confusion_matrix(y_target=y, 
                y_predicted=fin_pred, 
                binary=False)
    fig,ax=plot_confusion_matrix(conf_mat=cm
                ,show_absolute=True
                ,show_normed=False
                ,colorbar=False
                ,class_names=feature_names
                ,cmap='PuBu'
                ,fontcolor_threshold=0.6
                )
    plt.show()
# Out:
# Guassian, splits= 3
#                    precision    recall  f1-score   support
#
#        b'driving'       0.44      0.62      0.52       130
#         b'eating'       0.30      0.56      0.39       153
#          b'lying'       0.43      0.52      0.47       183
#        b'sitting'       0.69      0.34      0.46       642
# b'using_computer'       0.83      0.82      0.82       828
#        b'walking'       0.43      0.91      0.58        96
#
#          accuracy                           0.61      2032
#         macro avg       0.52      0.63      0.54      2032
#      weighted avg       0.66      0.61      0.61      2032
# Guassian, splits= 4
#                    precision    recall  f1-score   support
#
#        b'driving'       0.41      0.64      0.50       130
#         b'eating'       0.31      0.56      0.40       153
#          b'lying'       0.41      0.51      0.45       183
#        b'sitting'       0.67      0.31      0.43       642
# b'using_computer'       0.84      0.82      0.83       828
#        b'walking'       0.44      0.92      0.59        96
#
#          accuracy                           0.61      2032
#         macro avg       0.51      0.63      0.53      2032
#      weighted avg       0.66      0.61      0.60      2032
# Guassian, splits= 5
#                    precision    recall  f1-score   support
#
#        b'driving'       0.42      0.62      0.50       130
#         b'eating'       0.30      0.57      0.39       153
#          b'lying'       0.44      0.51      0.47       183
#        b'sitting'       0.68      0.33      0.45       642
# b'using_computer'       0.84      0.84      0.84       828
#        b'walking'       0.45      0.91      0.60        96
#
#          accuracy                           0.62      2032
#         macro avg       0.52      0.63      0.54      2032
#      weighted avg       0.67      0.62      0.61      2032
# Guassian, splits= 6
#                    precision    recall  f1-score   support
#
#        b'driving'       0.43      0.62      0.50       130
#         b'eating'       0.29      0.59      0.39       153
#          b'lying'       0.40      0.50      0.45       183
#        b'sitting'       0.67      0.31      0.42       642
# b'using_computer'       0.84      0.83      0.84       828
#        b'walking'       0.44      0.91      0.60        96
#
#          accuracy                           0.61      2032
#         macro avg       0.51      0.63      0.53      2032
#      weighted avg       0.66      0.61      0.60      2032
# Guassian, splits= 7
#                    precision    recall  f1-score   support
#
#        b'driving'       0.43      0.65      0.52       130
#         b'eating'       0.31      0.59      0.40       153
#          b'lying'       0.44      0.51      0.47       183
#        b'sitting'       0.67      0.32      0.43       642
# b'using_computer'       0.84      0.84      0.84       828
#        b'walking'       0.44      0.91      0.59        96
#
#          accuracy                           0.62      2032
#         macro avg       0.52      0.64      0.54      2032
#      weighted avg       0.67      0.62      0.61      2032
