# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_predict
from mlxtend.plotting import plot_confusion_matrix
from mlxtend.evaluate import confusion_matrix

from sklearn.neighbors import KNeighborsClassifier

import warnings
warnings.filterwarnings('ignore')

# %%
x = np.genfromtxt('preprocessed_x_bathroom.csv', delimiter=',')
y = np.genfromtxt('preprocessed_y_bathroom.csv', delimiter=',', dtype= None)

# %%
knn=KNeighborsClassifier()

# %%
feature_names=[]
for names in y:
  if names not in feature_names:
    feature_names.append(names)
#feature_names

# %%
for splits in range(3,8):
    fin_pred = cross_val_predict(knn, x, y, cv=splits)

    print("KNN, splits=",splits)
    print(classification_report(y, fin_pred))

    cm = confusion_matrix(y_target=y, 
                y_predicted=fin_pred, 
                binary=False)
    fig,ax=plot_confusion_matrix(conf_mat=cm
                ,show_absolute=True
                ,show_normed=False
                ,colorbar=False
                ,class_names=feature_names
                ,cmap='PuBu'
                ,fontcolor_threshold=0.6
                )
    plt.show()
# Out:
# KNN, splits= 3
#                    precision    recall  f1-score   support
#
#        b'driving'       0.31      0.26      0.28       130
#         b'eating'       0.24      0.18      0.20       153
#          b'lying'       0.44      0.59      0.51       183
#        b'sitting'       0.54      0.72      0.62       642
# b'using_computer'       0.81      0.70      0.75       828
#        b'walking'       0.00      0.00      0.00        96
#
#          accuracy                           0.60      2032
#         macro avg       0.39      0.41      0.39      2032
#      weighted avg       0.58      0.60      0.58      2032
# KNN, splits= 4
#                    precision    recall  f1-score   support
#
#        b'driving'       0.35      0.28      0.31       130
#         b'eating'       0.28      0.11      0.16       153
#          b'lying'       0.37      0.58      0.45       183
#        b'sitting'       0.57      0.79      0.66       642
# b'using_computer'       0.83      0.69      0.75       828
#        b'walking'       0.00      0.00      0.00        96
#
#          accuracy                           0.61      2032
#         macro avg       0.40      0.41      0.39      2032
#      weighted avg       0.60      0.61      0.59      2032
# KNN, splits= 5
#                    precision    recall  f1-score   support
#
#        b'driving'       0.34      0.29      0.31       130
#         b'eating'       0.25      0.10      0.15       153
#          b'lying'       0.35      0.58      0.43       183
#        b'sitting'       0.57      0.79      0.66       642
# b'using_computer'       0.84      0.68      0.75       828
#        b'walking'       0.00      0.00      0.00        96
#
#          accuracy                           0.60      2032
#         macro avg       0.39      0.41      0.38      2032
#      weighted avg       0.59      0.60      0.59      2032
# KNN, splits= 6
#                    precision    recall  f1-score   support
#
#        b'driving'       0.34      0.31      0.32       130
#         b'eating'       0.20      0.09      0.13       153
#          b'lying'       0.37      0.58      0.45       183
#        b'sitting'       0.57      0.79      0.66       642
# b'using_computer'       0.85      0.68      0.76       828
#        b'walking'       0.00      0.00      0.00        96
#
#          accuracy                           0.61      2032
#         macro avg       0.39      0.41      0.39      2032
#      weighted avg       0.60      0.61      0.59      2032
# KNN, splits= 7
#                    precision    recall  f1-score   support
#
#        b'driving'       0.33      0.30      0.32       130
#         b'eating'       0.26      0.08      0.13       153
#          b'lying'       0.35      0.57      0.43       183
#        b'sitting'       0.58      0.82      0.68       642
# b'using_computer'       0.85      0.68      0.76       828
#        b'walking'       0.00      0.00      0.00        96
#
#          accuracy                           0.61      2032
#         macro avg       0.40      0.41      0.39      2032
#      weighted avg       0.60      0.61      0.59      2032
