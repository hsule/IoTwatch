# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_predict
from mlxtend.plotting import plot_confusion_matrix
from mlxtend.evaluate import confusion_matrix

import warnings
warnings.filterwarnings('ignore')

from sklearn.linear_model import LogisticRegression

# %%
x = np.genfromtxt('preprocessed_x_bathroom.csv', delimiter=',')
y = np.genfromtxt('preprocessed_y_bathroom.csv', delimiter=',', dtype= None)

# %%
lr=LogisticRegression()

# %%
feature_names=[]
for names in y:
  if names not in feature_names:
    feature_names.append(names)
#feature_names

# %%
for splits in range(3,8):
    fin_pred = cross_val_predict(lr, x, y, cv=splits)

    print("Logistic, splits=",splits)
    print(classification_report(y, fin_pred))

    cm = confusion_matrix(y_target=y, 
                y_predicted=fin_pred, 
                binary=False)
    fig,ax=plot_confusion_matrix(conf_mat=cm
                ,show_absolute=True
                ,show_normed=False
                ,colorbar=False
                ,class_names=feature_names
                ,cmap='PuBu'
                ,fontcolor_threshold=0.6
                )
    plt.show()
# Out:
# Logistic, splits= 3
#                    precision    recall  f1-score   support
#
#        b'driving'       0.38      0.22      0.28       130
#         b'eating'       0.16      0.16      0.16       153
#          b'lying'       0.17      0.37      0.23       183
#        b'sitting'       0.51      0.49      0.50       642
# b'using_computer'       0.64      0.59      0.61       828
#        b'walking'       0.04      0.01      0.02        96
#
#          accuracy                           0.45      2032
#         macro avg       0.32      0.31      0.30      2032
#      weighted avg       0.48      0.45      0.46      2032
# Logistic, splits= 4
#                    precision    recall  f1-score   support
#
#        b'driving'       0.36      0.28      0.31       130
#         b'eating'       0.15      0.14      0.15       153
#          b'lying'       0.18      0.37      0.24       183
#        b'sitting'       0.53      0.51      0.52       642
# b'using_computer'       0.65      0.61      0.63       828
#        b'walking'       0.10      0.02      0.03        96
#
#          accuracy                           0.47      2032
#         macro avg       0.33      0.32      0.31      2032
#      weighted avg       0.49      0.47      0.48      2032
# Logistic, splits= 5
#                    precision    recall  f1-score   support
#
#        b'driving'       0.38      0.28      0.32       130
#         b'eating'       0.14      0.14      0.14       153
#          b'lying'       0.18      0.38      0.25       183
#        b'sitting'       0.51      0.47      0.49       642
# b'using_computer'       0.63      0.60      0.61       828
#        b'walking'       0.06      0.02      0.03        96
#
#          accuracy                           0.45      2032
#         macro avg       0.32      0.31      0.31      2032
#      weighted avg       0.47      0.45      0.46      2032
# Logistic, splits= 6
#                    precision    recall  f1-score   support
#
#        b'driving'       0.32      0.23      0.27       130
#         b'eating'       0.12      0.11      0.11       153
#          b'lying'       0.18      0.36      0.24       183
#        b'sitting'       0.53      0.52      0.52       642
# b'using_computer'       0.65      0.62      0.63       828
#        b'walking'       0.04      0.01      0.02        96
#
#          accuracy                           0.47      2032
#         macro avg       0.31      0.31      0.30      2032
#      weighted avg       0.48      0.47      0.47      2032
# Logistic, splits= 7
#                    precision    recall  f1-score   support
#
#        b'driving'       0.42      0.30      0.35       130
#         b'eating'       0.15      0.15      0.15       153
#          b'lying'       0.20      0.37      0.26       183
#        b'sitting'       0.52      0.50      0.51       642
# b'using_computer'       0.65      0.63      0.64       828
#        b'walking'       0.05      0.02      0.03        96
#
#          accuracy                           0.48      2032
#         macro avg       0.33      0.33      0.32      2032
#      weighted avg       0.49      0.48      0.48      2032
